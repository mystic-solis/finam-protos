# %%
# from finam_protos.finam_grpc.grpc.tradeapi.v1


from finam_grpc.grpc.tradeapi.v1.auth import auth_service_pb2 as auth_service
from finam_grpc.grpc.tradeapi.v1.auth.auth_service_pb2_grpc import AuthServiceStub
